# %%
import matplotlib.pyplot as plt

# %%
plt.plot([4,0],[0,14])
plt.plot([12,0],[0,2])
# plt.plot([4,0],[0,14],'ro',color='black')
plt.show()

def plot_rhs(rhs)
    
    x1_0 = rhs/100
    x2_0 = rhs/50
    plt.plot([x1_0,0],[0,x2_0])
